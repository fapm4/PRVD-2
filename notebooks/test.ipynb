# %%
import pandas as pd
import os
import folium
from folium import plugins
from pyproj import Transformer

# %%
PATH = os.getcwd()

# %%
df = pd.read_csv(f"{PATH}/data/ruido.csv", sep=";")
df.head()
# Out:
#    NMT  anio  mes  dia tipo  LAEQ  \
# 0    1  2021    1    1    D  62.6
# 1    1  2021    1    1    E  64.4
# 2    1  2021    1    1    N  62.6
# 3    1  2021    1    1    T  63.3
# 4    2  2021    1    1    D  65.8
#
#                                            DIRECCION  X (ETRS89)  Y (ETRS89)
# 0  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 1  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 2  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 3  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 4  Glorieta de Carlos V Plaza del Emperador Carlo...      441328     4473396

# %%
# Creamos el transformador de ETRS89 UTM zona 30N (EPSG:25830) a WGS84 (EPSG:4326)
transformer = Transformer.from_crs("EPSG:25830", "EPSG:4326")

# Añadimos las columnas de latitud y longitud al dataframe
df['lat'], df['lon'] = transformer.transform(df['X (ETRS89)'], df['Y (ETRS89)'])

df.head()
# Out:
#    NMT  anio  mes  dia tipo  LAEQ  \
# 0    1  2021    1    1    D  62.6
# 1    1  2021    1    1    E  64.4
# 2    1  2021    1    1    N  62.6
# 3    1  2021    1    1    T  63.3
# 4    2  2021    1    1    D  65.8
#
#                                            DIRECCION  X (ETRS89)  Y (ETRS89)  \
# 0  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 1  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 2  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 3  Paseo de Recoletos Frente al nº 23 del Paseo d...      441303     4474895
# 4  Glorieta de Carlos V Plaza del Emperador Carlo...      441328     4473396
#
#          lat       lon
# 0  40.422616 -3.691925
# 1  40.422616 -3.691925
# 2  40.422616 -3.691925
# 3  40.422616 -3.691925
# 4  40.409114 -3.691492

# %%
# Creamos un mapa centrado en Madrid
mapa_madrid = folium.Map(
    location=[40.4168, -3.7038],  # Coordenadas del centro de Madrid
    zoom_start=12
)

marker_cluster = plugins.MarkerCluster().add_to(mapa_madrid)

# Visualización usando las coordenadas convertidas
for idx, row in df.drop_duplicates(subset=['NMT']).iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"Estación: {row['DIRECCION']}<br>Ruido promedio: {df_calor[df_calor['NMT']==row['NMT']]['LAEQ'].values[0]:.1f} dB",
    ).add_to(marker_cluster)

display(mapa_madrid)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15e627154134829fe505610c8f0d4a78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15e627154134829fe505610c8f0d4a78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15e627154134829fe505610c8f0d4a78 = L.map(
#                 &quot;map_15e627154134829fe505610c8f0d4a78&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_740dbc3452d243751408e5b195dd7cc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_740dbc3452d243751408e5b195dd7cc0.addTo(map_15e627154134829fe505610c8f0d4a78);
#
#
#             var marker_cluster_22f0b3660ff5bde76b4cfa8a64bfd272 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_fad3bf45bcca9a67faeb48e515414d07 = L.marker(
#                 [40.42261600702235, -3.6919247860339652],
#                 {
# }
#             ).addTo(marker_cluster_22f0b3660ff5bde76b4cfa8a64bfd272);
#
#
#         var popup_8419a1007dca163d1b0cb2ef162f2ec6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ace6c38d227acf2f60ba747a535866c = $(`&lt;div id=&quot;html_4ace6c38d227acf2f60ba747a535866c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Paseo de Recoletos Frente al nº 23 del Paseo de Recoletos&lt;br&gt;Ruido promedio: 64.1 dB&lt;/div&gt;`)[0];
#                 popup_8419a1007dca163d1b0cb2ef162f2ec6.setContent(html_4ace6c38d227acf2f60ba747a535866c);
#
#
#
#         marker_fad3bf45bcca9a67faeb48e515414d07.bindPopup(popup_8419a1007dca163d1b0cb2ef162f2ec6)
#         ;
#
#
#
#
#             var marker_ef2b6269439f7fc1836607629366e07b = L.marker(
#                 [40.40911403486669, -3.6914918443505895],
#                 {
# }
#             ).addTo(marker_cluster_22f0b3660ff5bde76b4cfa8a64bfd272);
#
#
#         var popup_762ccdde14bc19d79986e04833ea1c87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76ef3561618aee59cc9f896b70e50ab8 = $(`&lt;div id=&quot;html_76ef3561618aee59cc9f896b70e50ab8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Glorieta de Carlos V Plaza del Emperador Carlos V, junto al nº 1 del Paseo de la Infanta Isabel&lt;br&gt;Ruido promedio: 67.1 dB&lt;/div&gt;`)[0];
#                 popup_762ccdde14bc19d79986e04833ea1c87.setContent(html_76ef3561618aee59cc9f896b70e50ab8);
#
#
#
#         marker_ef2b6269439f7fc1836607629366e07b.bindPopup(popup_762ccdde14bc19d79986e04833ea1c87)
#         ;
#
#
#
#
#             var marker_fae31d3b17647ed2b292ad8c2ef8fdca = L.marker(
#                 [40.41920580444544, -3.7031703762245103],
#                 {
# }
#             ).addTo(marker_cluster_22f0b3660ff5bde76b4cfa8a64bfd272);
#
#
#         var popup_4061603b62ffce67594ae2a03ee2226b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ce0c9efb3dce609d02fce004acf0a0f = $(`&lt;div id=&quot;html_9ce0c9efb3dce609d02fce004acf0a0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Plaza del Carmen Plaza del Carmen, frente al nº 3 de la Calle de la Salud&lt;br&gt;Ruido promedio: 60.0 dB&lt;/div&gt;`)[0];
#                 popup_4061603b62ffce67594ae2a03ee2226b.setContent(html_9ce0c9efb3dce609d02fce004acf0a0f);
#
#
#
#         marker_fae31d3b17647ed2b292ad8c2ef8fdca.bindPopup(popup_4061603b62ffce67594ae2a03ee2226b)
#         ;
#
#
#
#
#             var marker_3ffc2f851d3d7b09edb4fa527f6f8d3f = L.marker(
#                 [40.47823557812532, -3.7115369854526388],
#                 {
# }
#             ).addTo(marker_cluster_22f0b3660ff5bde76b4cfa8a64bfd272);
#
#
#         var popup_25c1a379cf2d35a1567266c41892a41d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_066cfcc5ef99b649a485f8d843f43e11 = $(`&lt;div id=&quot;html_066cfcc5ef99b649a485f8d843f43e11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Barrio del Pilar Parque de La Vaguada, junto nº 42 de Avenida Monforte de Lemos&lt;br&gt;Ruido promedio: 58.2 dB&lt;/div&gt;`)[0];
#                 popup_25c1a379cf2d35a1567266c41892a41d.setCon

# %%
# 1. Mapa de calor del ruido promedio
df_promedio = df.groupby('NMT')['LAEQ'].mean().reset_index()
df_ubicaciones = df.drop_duplicates(subset=['NMT'])[['NMT', 'lat', 'lon']]
df_calor = pd.merge(df_promedio, df_ubicaciones, on='NMT')

# Crear el mapa de calor
mapa_calor = folium.Map(location=[40.4168, -3.7038], zoom_start=12)

# Añadir el mapa de calor al mapa
plugins.HeatMap(df_calor[['lat', 'lon', 'LAEQ']].values.tolist()).add_to(mapa_calor)

# Mostrar el mapa
display(mapa_calor)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba6482acf090c7573c5e6c5a324afca3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba6482acf090c7573c5e6c5a324afca3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba6482acf090c7573c5e6c5a324afca3 = L.map(
#                 &quot;map_ba6482acf090c7573c5e6c5a324afca3&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f83f94039c4f344d4873cb415f576f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f83f94039c4f344d4873cb415f576f5.addTo(map_ba6482acf090c7573c5e6c5a324afca3);
#
#
#             var heat_map_5386eb18d5c26e4307c8c8d3d41ba241 = L.heatLayer(
#                 [[40.42261600702235, -3.6919247860339652, 64.11362916006338], [40.40911403486669, -3.6914918443505895, 67.095], [40.41920580444544, -3.7031703762245103, 60.02192638997651], [40.47823557812532, -3.7115369854526388, 58.239140625000005], [40.43756882025155, -3.690781091956053, 66.93399366085578], [40.42155597807561, -3.682318653971866, 62.976796536796535], [40.4455420045081, -3.7071356559258084, 61.964437450826125], [40.451477125215185, -3.677349714893065, 64.5050259965338], [40.42880746738279, -3.668575142108873, 60.932839313572536], [40.388147775589644, -3.6515249609331666, 55.5017363851618], [40.38503762741975, -3.7187669764462963, 62.69624900239425], [40.44004547200534, -3.6392442249431975, 57.52392494136044], [40.347143014079855, -3.7133131462632876, 55.415457413249214], [40.394784580833274, -3.7318320378030427, 54.7903605015674], [40.407864650538556, -3.741897000218921, 57.45213114754099], [40.40794859659828, -3.6453045837071167, 58.17240031274433], [40.41936116339834, -3.7473393933262193, 46.265824915824915], [40.379052933335444, -3.6025368457837392, 65.75128805620608], [40.45931166693425, -3.580242365222784, 58.22676056338028], [40.476916324453015, -3.5800281742880244, 56.117284991568305], [40.37519588098817, -3.777831780168607, 64.10712607674236], [40.51807282868191, -3.7746053805243043, 54.708079268292686], [40.46072839679466, -3.6163462756169507, 56.97544816835542], [40.49420498643456, -3.660515049712327, 58.932754538279404], [40.39809677088626, -3.6868188168319427, 53.298006644518274], [40.43988660092818, -3.6903685487127893, 58.236866718628214], [40.46558092482935, -3.6887442849672074, 63.44346774193548], [40.37301141459917, -3.612142112261931, 57.44045954045954], [40.462364108612064, -3.5805635038159513, 53.299847328244276], [40.50054778646142, -3.6897272697246732, 53.224303405572755]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_5386eb18d5c26e4307c8c8d3d41ba241.addTo(map_ba6482acf090c7573c5e6c5a324afca3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 3. Mapa con círculos proporcionales al nivel de ruido normalizado
mapa_circulos = folium.Map(
    location=[40.4168, -3.7038],
    zoom_start=12
)

# Calculamos el rango de valores para normalizar
min_db = df_calor['LAEQ'].min()
max_db = df_calor['LAEQ'].max()

# Definimos el rango de tamaños que queremos para los círculos
min_radius = 5
max_radius = 30

for idx, row in df_calor.iterrows():
    # Normalizamos el radio entre min_radius y max_radius
    radius = min_radius + (row['LAEQ'] - min_db) * (max_radius - min_radius) / (max_db - min_db)
    
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=radius,
        popup=f"Estación: {df[df['NMT']==row['NMT']]['DIRECCION'].iloc[0]}<br>Ruido: {row['LAEQ']:.1f} dB",
        color='blue',
        fill=True,
        fill_color='blue',
        tooltip=f"{row['LAEQ']:.1f} dB"  # Añadido tooltip para ver el valor al pasar el mouse
    ).add_to(mapa_circulos)

display(mapa_circulos)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17534eb4931bf7f515e84e0568596839 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17534eb4931bf7f515e84e0568596839&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17534eb4931bf7f515e84e0568596839 = L.map(
#                 &quot;map_17534eb4931bf7f515e84e0568596839&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cddcf6c153d7cc1f5c43e8eeee36609d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cddcf6c153d7cc1f5c43e8eeee36609d.addTo(map_17534eb4931bf7f515e84e0568596839);
#
#
#             var circle_marker_ded91ed87eaef4197a07a7fec06ec972 = L.circleMarker(
#                 [40.42261600702235, -3.6919247860339652],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 26.42164076603098, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17534eb4931bf7f515e84e0568596839);
#
#
#         var popup_449d4b1b00dbcd93be3f8be4422e8c63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2640ead58b8bc56835b16a0e5652de0 = $(`&lt;div id=&quot;html_a2640ead58b8bc56835b16a0e5652de0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Paseo de Recoletos Frente al nº 23 del Paseo de Recoletos&lt;br&gt;Ruido: 64.1 dB&lt;/div&gt;`)[0];
#                 popup_449d4b1b00dbcd93be3f8be4422e8c63.setContent(html_a2640ead58b8bc56835b16a0e5652de0);
#
#
#
#         circle_marker_ded91ed87eaef4197a07a7fec06ec972.bindPopup(popup_449d4b1b00dbcd93be3f8be4422e8c63)
#         ;
#
#
#
#
#             circle_marker_ded91ed87eaef4197a07a7fec06ec972.bindTooltip(
#                 `&lt;div&gt;
#                      64.1 dB
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_ebdbcf9fc801aba6a7bf502b91563ab4 = L.circleMarker(
#                 [40.40911403486669, -3.6914918443505895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 30.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17534eb4931bf7f515e84e0568596839);
#
#
#         var popup_ae1b15d8216b2e2775a7c28e6cfd6ab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f766c0d264ebe8b5ee905c39a32e31a = $(`&lt;div id=&quot;html_4f766c0d264ebe8b5ee905c39a32e31a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Glorieta de Carlos V Plaza del Emperador Carlos V, junto al nº 1 del Paseo de la Infanta Isabel&lt;br&gt;Ruido: 67.1 dB&lt;/div&gt;`)[0];
#                 popup_ae1b15d8216b2e2775a7c28e6cfd6ab1.setContent(html_4f766c0d264ebe8b5ee905c39a32e31a);
#
#
#
#         circle_marker_ebdbcf9fc801aba6a7bf502b91563ab4.bindPopup(popup_ae1b15d8216b2e2775a7c28e6cfd6ab1)
#         ;
#
#
#
#
#             circle_marker_ebdbcf9fc801aba6a7bf502b91563ab4.bindTooltip(
#                 `&lt;div&gt;
#                      67.1 dB
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4d8680249c7900834591515c8189aecd = L.circleMarker(
#                 [40.41920580444544, -3.7031703762245103],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21.51061722146975, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_17534eb4931bf7f515e84e0568596839);
#
#
#         var popup_2db2a459722b2fad8a2076058dc6ed0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2

# %%
# Creamos el mapa base
mapa_combinado = folium.Map(
    location=[40.4168, -3.7038],
    zoom_start=12
)

# 1. Capa de clusters de marcadores
marker_cluster = plugins.MarkerCluster(name='Estaciones (clusters)').add_to(mapa_combinado)

for idx, row in df.drop_duplicates(subset=['NMT']).iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"Estación: {row['DIRECCION']}<br>Ruido promedio: {df_calor[df_calor['NMT']==row['NMT']]['LAEQ'].values[0]:.1f} dB",
    ).add_to(marker_cluster)

# 2. Capa de mapa de calor
heat_data = [[row['lat'], row['lon'], row['LAEQ']] for idx, row in df_calor.iterrows()]
heat_group = folium.FeatureGroup(name='Mapa de calor')
plugins.HeatMap(heat_data).add_to(heat_group)
heat_group.add_to(mapa_combinado)

# 3. Capa de círculos proporcionales
circle_group = folium.FeatureGroup(name='Círculos de ruido')

min_db = df_calor['LAEQ'].min()
max_db = df_calor['LAEQ'].max()
min_radius = 5
max_radius = 30

for idx, row in df_calor.iterrows():
    radius = min_radius + (row['LAEQ'] - min_db) * (max_radius - min_radius) / (max_db - min_db)
    
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=radius,
        popup=f"Estación: {df[df['NMT']==row['NMT']]['DIRECCION'].iloc[0]}<br>Ruido: {row['LAEQ']:.1f} dB",
        color='blue',
        fill=True,
        fill_color='blue',
        tooltip=f"{row['LAEQ']:.1f} dB"
    ).add_to(circle_group)

circle_group.add_to(mapa_combinado)

# Añadimos el control de capas
folium.LayerControl().add_to(mapa_combinado)

# Mostramos el mapa
display(mapa_combinado)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1276e05f2d10fd33c02e879e2a0325e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1276e05f2d10fd33c02e879e2a0325e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1276e05f2d10fd33c02e879e2a0325e = L.map(
#                 &quot;map_c1276e05f2d10fd33c02e879e2a0325e&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_718cdc73bce76d4406f5102d955c4d95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_718cdc73bce76d4406f5102d955c4d95.addTo(map_c1276e05f2d10fd33c02e879e2a0325e);
#
#
#             var marker_cluster_4bdb82786eb9a9d6c3efcdee5e0e56ba = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_30c68b8e897400d7bfc1709050a4349b = L.marker(
#                 [40.42261600702235, -3.6919247860339652],
#                 {
# }
#             ).addTo(marker_cluster_4bdb82786eb9a9d6c3efcdee5e0e56ba);
#
#
#         var popup_4f25f6c6e34a6202f7727a189717136a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c20976b6daec308f23db6bb01e9c975b = $(`&lt;div id=&quot;html_c20976b6daec308f23db6bb01e9c975b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Paseo de Recoletos Frente al nº 23 del Paseo de Recoletos&lt;br&gt;Ruido promedio: 64.1 dB&lt;/div&gt;`)[0];
#                 popup_4f25f6c6e34a6202f7727a189717136a.setContent(html_c20976b6daec308f23db6bb01e9c975b);
#
#
#
#         marker_30c68b8e897400d7bfc1709050a4349b.bindPopup(popup_4f25f6c6e34a6202f7727a189717136a)
#         ;
#
#
#
#
#             var marker_533743e0556b4d5a02e0242f239cb149 = L.marker(
#                 [40.40911403486669, -3.6914918443505895],
#                 {
# }
#             ).addTo(marker_cluster_4bdb82786eb9a9d6c3efcdee5e0e56ba);
#
#
#         var popup_f93ba7bf56d363fb920f8a0103b842c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fefdffa7989b5170607c5307b1d647ed = $(`&lt;div id=&quot;html_fefdffa7989b5170607c5307b1d647ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Glorieta de Carlos V Plaza del Emperador Carlos V, junto al nº 1 del Paseo de la Infanta Isabel&lt;br&gt;Ruido promedio: 67.1 dB&lt;/div&gt;`)[0];
#                 popup_f93ba7bf56d363fb920f8a0103b842c1.setContent(html_fefdffa7989b5170607c5307b1d647ed);
#
#
#
#         marker_533743e0556b4d5a02e0242f239cb149.bindPopup(popup_f93ba7bf56d363fb920f8a0103b842c1)
#         ;
#
#
#
#
#             var marker_44c7bcc6f3cdc4bf859c669cd36afd1b = L.marker(
#                 [40.41920580444544, -3.7031703762245103],
#                 {
# }
#             ).addTo(marker_cluster_4bdb82786eb9a9d6c3efcdee5e0e56ba);
#
#
#         var popup_21ea691ea8eeb1a3e4f74c032d8890c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67fcc842b9c8d864885ad9cb7b18bf88 = $(`&lt;div id=&quot;html_67fcc842b9c8d864885ad9cb7b18bf88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Plaza del Carmen Plaza del Carmen, frente al nº 3 de la Calle de la Salud&lt;br&gt;Ruido promedio: 60.0 dB&lt;/div&gt;`)[0];
#                 popup_21ea691ea8eeb1a3e4f74c032d8890c6.setContent(html_67fcc842b9c8d864885ad9cb7b18bf88);
#
#
#
#         marker_44c7bcc6f3cdc4bf859c669cd36afd1b.bindPopup(popup_21ea691ea8eeb1a3e4f74c032d8890c6)
#         ;
#
#
#
#
#             var marker_f795e8238991f0128da225420971fb30 = L.marker(
#                 [40.47823557812532, -3.7115369854526388],
#                 {
# }
#             ).addTo(marker_cluster_4bdb82786eb9a9d6c3efcdee5e0e56ba);
#
#
#         var popup_759f977bb4584dfebfcd0aa812051c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1d1904600f43bb8d13047dcc79027e3 = $(`&lt;div id=&quot;html_c1d1904600f43bb8d13047dcc79027e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estación: Barrio del Pilar Parque de La Vaguada, junto

# %%
# Creamos el mapa base
mapa_combinado = folium.Map(
    location=[40.4168, -3.7038],
    zoom_start=12
)

# Definimos colores para cada tipo de medición
colores_tipo = {
    'D': 'blue',      # Diurno
    'E': 'green',     # Vespertino
    'N': 'red',       # Nocturno
    'T': 'purple'     # Total
}

# Definimos etiquetas descriptivas para cada tipo
etiquetas_tipo = {
    'D': 'Diurno',
    'E': 'Vespertino',
    'N': 'Nocturno',
    'T': 'Total'
}

# Iteramos por tipo
for tipo in sorted(df['tipo'].unique()):
    # Filtramos datos para este tipo
    df_filtrado = df[df['tipo'] == tipo]
    df_promedio = df_filtrado.groupby('NMT')['LAEQ'].mean().reset_index()
    df_ubicaciones = df_filtrado.drop_duplicates(subset=['NMT'])[['NMT', 'lat', 'lon', 'DIRECCION']]
    df_calor = pd.merge(df_promedio, df_ubicaciones, on='NMT')
    
    # 2. Capa de mapa de calor
    heat_data = [[row['lat'], row['lon'], row['LAEQ']] for idx, row in df_calor.iterrows()]
    heat_group = folium.FeatureGroup(name=f'Calor {etiquetas_tipo[tipo]}')
    plugins.HeatMap(heat_data).add_to(heat_group)
    heat_group.add_to(mapa_combinado)
    

# Añadimos el control de capas
folium.LayerControl(collapsed=False).add_to(mapa_combinado)

# Mostramos el mapa
display(mapa_combinado)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1c865873a67030f59a966b933b562bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1c865873a67030f59a966b933b562bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1c865873a67030f59a966b933b562bb = L.map(
#                 &quot;map_d1c865873a67030f59a966b933b562bb&quot;,
#                 {
#                     center: [40.4168, -3.7038],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0aebc74b0393f8c16f3ecf51cf2bf54d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0aebc74b0393f8c16f3ecf51cf2bf54d.addTo(map_d1c865873a67030f59a966b933b562bb);
#
#
#             var feature_group_702de506be365485bf01131ca7f4fc17 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var heat_map_ee0435f91ccec56cfdd0a63e0833389a = L.heatLayer(
#                 [[40.42261600702235, -3.6919247860339652, 65.66190476190476], [40.40911403486669, -3.6914918443505895, 68.38354037267081], [40.41920580444544, -3.7031703762245103, 61.11125], [40.47823557812532, -3.7115369854526388, 60.690909090909095], [40.43756882025155, -3.690781091956053, 68.8536507936508], [40.42155597807561, -3.682318653971866, 64.5370242214533], [40.4455420045081, -3.7071356559258084, 64.10534591194968], [40.451477125215185, -3.677349714893065, 67.32291666666667], [40.42880746738279, -3.668575142108873, 63.00750000000001], [40.388147775589644, -3.6515249609331666, 57.40854430379746], [40.38503762741975, -3.7187669764462963, 64.47444089456869], [40.44004547200534, -3.6392442249431975, 59.930625], [40.347143014079855, -3.7133131462632876, 56.985126582278475], [40.394784580833274, -3.7318320378030427, 57.45454545454545], [40.407864650538556, -3.741897000218921, 59.88881578947369], [40.40794859659828, -3.6453045837071167, 60.5328125], [40.41936116339834, -3.7473393933262193, 48.74530201342282], [40.379052933335444, -3.6025368457837392, 67.46875], [40.45931166693425, -3.580242365222784, 60.38996865203762], [40.476916324453015, -3.5800281742880244, 58.13277027027027], [40.37519588098817, -3.777831780168607, 67.01598746081504], [40.51807282868191, -3.7746053805243043, 57.182012195121956], [40.46072839679466, -3.6163462756169507, 59.32990654205608], [40.49420498643456, -3.660515049712327, 62.0981072555205], [40.39809677088626, -3.6868188168319427, 55.12956810631229], [40.43988660092818, -3.6903685487127893, 59.958878504672896], [40.46558092482935, -3.6887442849672074, 65.25032258064516], [40.37301141459917, -3.612142112261931, 59.8288], [40.462364108612064, -3.5805635038159513, 55.77378048780488], [40.50054778646142, -3.6897272697246732, 55.910835913312695]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_ee0435f91ccec56cfdd0a63e0833389a.addTo(feature_group_702de506be365485bf01131ca7f4fc17);
#
#
#             feature_group_702de506be365485bf01131ca7f4fc17.addTo(map_d1c865873a67030f59a966b933b562bb);
#
#
#             var feature_group_075242890538c4519a0e383629fc30f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var heat_map_bc4cfb5dc7bb67169f2e1273e02a38e8 = L.heatLayer(
#                 [[40.42261600702235, -3.6919247860339652, 65.34668769716089], [40.40911403486669, -3.6914918443505895, 68.27781250000001], [40.41920580444544, -3.7031703762245103, 61.558437500000004], [40.47823557812532, -3.7115369854526388, 60.88473520249221], [40.43756882025155, -3.690781091956053, 68.42397476340695], [40.42155597807561, -3.682318653971866, 64.40588235294118], [40.4455420045081, -3.7071356559258084, 63.325471698113205], [40.451477125215185, -3.677349714893065, 66.49722222222222], [40.42880746738279, -3.668575142108873, 62.75638629283489], [40.388147775589644, -3.6515249609331666, 57.34276729559748], [40.38503762741975, -3.7187669764462963, 64.08949044585987], [40.44004547200534, -3.6392442249431975, 58.9428125], [40.347143014079855, -3.7133131462632876, 58.4619496855346], [40.394784580833274, -3.7318320378030427, 56.33918495297806], [40.407864650538556, -3.741897000218921, 59.183061889250816], [40.40794859659828, -3.6453045837071167, 59.954375000000006], [40.41936116339834, -3.7473393933262193, 46.72986577181208], [40.379052933335444, -3.6025368457837392, 66.95389408099689], [40.45931166693425, -3.580242365222784, 58.81614906832298], [40.476916324453015, -3.5800281742880244, 56.65728476821192], [40.37519588098817, -3.777831780168607, 65.3259375], [40.51807282868191, -3.7746053805243043, 56.14420731707317], [40.460728396
